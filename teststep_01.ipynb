# %% [markdown]
# <a href="https://colab.research.google.com/github/tatsumidevelop/BackupHomeWork/blob/main/teststep_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
# coding: utf-8
import os
import matplotlib.pyplot as plt
from matplotlib.image import imread
from pathlib import Path
os.chdir('/content/drive/MyDrive/python/deep1')
dataset_dir = Path().resolve()
print(dataset_dir)
img = imread('dataset/lena.png') # 画像の読み込み
plt.imshow(img)
plt.show()
# Out:
# /content/drive/MyDrive/python/deep1

# %%
# !cd /content/drive/MyDrive/python/deep1
# !ls
import sys, os

sys.path.append(os.pardir)

from dataset.mnist import load_mnist

(x_train, t_train), (x_test, t_test) = load_mnist(flatten=True, normalize=False)

print(x_train.shape)

print(t_train.shape)

print(x_test.shape)

print(t_test.shape)
# Out:
# hungry.py    __pycache__       t10k-images-idx3-ubyte.gz   zlist.BAK
# img_show.py  simple_graph.py   t10k-labels-idx1-ubyte.gz   zlist.txt
# man.py	     sin_cos_graph.py  train-images-idx3-ubyte.gz
# mnist.pkl    sin_graph.py      train-labels-idx1-ubyte.gz
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)
